# %% [markdown]
# <a href="https://colab.research.google.com/github/michhottinger/MedCab2bw/blob/master/MedCab2bw.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#open and view data

import pandas as pd

url = 'https://github.com/michhottinger/MedCab2bw/blob/master/cannabis.csv?raw=true'
df = pd.read_csv(url)
df.head(5)

url2 = 'https://raw.githubusercontent.com/DNason1999/simple_repository/master/df.csv'
df2 = pd.read_csv(url2)

# %%
#clean data as needed and prep for joining
df.isnull().sum()
# Out:
# Strain          0
# Type            0
# Rating          0
# Effects         0
# Flavor         46
# Description    33
# dtype: int64

# %%
df.dtypes
# Out:
# Strain          object
# Type            object
# Rating         float64
# Effects         object
# Flavor          object
# Description     object
# dtype: object

# %%
df_1 = df[['Strain', 'Rating', 'Description']].sort_values('Strain', ascending=True)
df_1
# Out:
#            Strain  Rating                                        Description
# 0          100-Og     4.0  $100 OG is a 50/50 hybrid strain that packs a ...
# 2            1024     4.4  1024 is a sativa-dominant hybrid bred in Spain...
# 3        13-Dawgs     4.2  13 Dawgs is a hybrid of G13 and Chemdawg genet...
# 4        24K-Gold     4.6  Also known as Kosher Tangie, 24k Gold is a 60%...
# 5      3-Bears-Og     0.0  3 Bears OG by Mephisto Genetics is an autoflow...
# ...           ...     ...                                                ...
# 2346      Zeus-Og     4.7  Zeus OG is a hybrid cross between Pineapple OG...
# 2347     Zkittlez     4.6  Zkittlez is an indica-dominant mix of Grape Ap...
# 2348  Zombie-Kush     5.0  Zombie Kush by Ripper Seeds comes from two dif...
# 2349    Zombie-Og     4.4  If you’re looking to transform into a flesh-ea...
# 2350     Zoom-Pie     4.6  Zoom Pie (also known as Zombie Pie) is a heavy...
#
# [2351 rows x 3 columns]

# %%
df2.head()
# Out:
#   Unnamed: 0  ...                                        ʻAlenuihāhā
# 0         id  ...                                               2162
# 1       race  ...                                             hybrid
# 2    flavors  ...                 ['Sweet', 'Tropical', 'Pineapple']
# 3    effects  ...  {'positive': ['Euphoric', 'Happy', 'Creative',...
# 4   positive  ...  ['Euphoric', 'Happy', 'Creative', 'Energetic',...
#
# [5 rows x 1971 columns]

# %%
df2t = df2.T

df2t.head()
# Out:
#                     0  ...                                                  6
# Unnamed: 0         id  ...                                            medical
# Afpak               1  ...  ['Depression', 'Insomnia', 'Pain', 'Stress', '...
# African             2  ...  ['Depression', 'Pain', 'Stress', 'Lack of Appe...
# Afternoon Delight   3  ...  ['Depression', 'Insomnia', 'Pain', 'Stress', '...
# Afwreck             4  ...  ['Pain', 'Stress', 'Headache', 'Fatigue', 'Hea...
#
# [5 rows x 7 columns]

# %%
df_2 = df2t.reset_index().rename(columns={'index': 'Strain', 1: 'race', 2: 'flavors', 3: 'effects', 4: 'positive', 5: 'negative', 6: 'medical'}).drop([0])
df_2.head()
# Out:
#               Strain  ...                                            medical
# 1              Afpak  ...  ['Depression', 'Insomnia', 'Pain', 'Stress', '...
# 2            African  ...  ['Depression', 'Pain', 'Stress', 'Lack of Appe...
# 3  Afternoon Delight  ...  ['Depression', 'Insomnia', 'Pain', 'Stress', '...
# 4            Afwreck  ...  ['Pain', 'Stress', 'Headache', 'Fatigue', 'Hea...
# 5       Agent Orange  ...  ['Depression', 'Pain', 'Stress', 'Nausea', 'He...
#
# [5 rows x 8 columns]

# %%
df_2.dtypes
# Out:
# Strain      object
# 0           object
# race        object
# flavors     object
# effects     object
# positive    object
# negative    object
# medical     object
# dtype: object

# %%
df_1['Strain']=df_1['Strain'] = df['Strain'].str.replace('-', ' ')
df_1.head()
# Out:
#        Strain  Rating                                        Description
# 0      100 Og     4.0  $100 OG is a 50/50 hybrid strain that packs a ...
# 2        1024     4.4  1024 is a sativa-dominant hybrid bred in Spain...
# 3    13 Dawgs     4.2  13 Dawgs is a hybrid of G13 and Chemdawg genet...
# 4    24K Gold     4.6  Also known as Kosher Tangie, 24k Gold is a 60%...
# 5  3 Bears Og     0.0  3 Bears OG by Mephisto Genetics is an autoflow...

# %%
#join dfs
df_join = df_2.set_index('Strain').join(df_1.set_index('Strain'))
df_join
# Out:
#                       0  ...                                        Description
# Strain                   ...
# Afpak                 1  ...  Afpak, named for its direct Afghani and Pakist...
# African               2  ...  African refers to the indigenous varieties of ...
# Afternoon Delight     3  ...  Afternoon Delight, created by Colorado Seed In...
# Afwreck               4  ...  Afwreck is a hybrid cross of Afghani and Train...
# Agent Orange          5  ...  Don’t let the name scare you! The only herbici...
# ...                 ...  ...                                                ...
# Zeus OG            2158  ...                                                NaN
# Zkittlez           2159  ...  Zkittlez is an indica-dominant mix of Grape Ap...
# Zombie OG          2160  ...                                                NaN
# Zoom Pie           2161  ...  Zoom Pie (also known as Zombie Pie) is a heavy...
# ʻAlenuihāhā        2162  ...                                                NaN
#
# [1970 rows x 9 columns]

# %%
df_join.shape
# Out:
# (1970, 9)
